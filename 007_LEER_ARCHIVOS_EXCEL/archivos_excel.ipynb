# %% [markdown]
# ## **Leyendo archivos Excel**

# %% [markdown]
# ### importando archivos Excel

# %%
import pandas as pd

# Leer la hoja de cálculo de un archivo Excel
datos_co2 = pd.read_excel("emisiones_CO2.xlsx")

# %%
datos_co2.head()  # Muestra las primeras filas del DataFrame
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    0.0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    0.0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    0.0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    0.0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    0.0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN

# %% [markdown]
# #### averiguar hojas del excel

# %%
pd.ExcelFile("emisiones_CO2.xlsx").sheet_names  
# Muestra los nombres de las hojas en el archivo Excel
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %%
percapita = pd.read_excel("emisiones_CO2.xlsx",sheet_name= 'emisiones_percapita')

# %%
percapita.tail()  
# Muestra las ultimos filas del DataFrame
# Out:
#          País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 63099  Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100  Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101  Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102  Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103  Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gas   Cemento    Quema    Otros
# 63099   940144.0  198416.0  51579.0  39776.0
# 63100   979965.0  204225.0  53634.0  39366.0
# 63101   984878.0  208309.0  56569.0  39490.0
# 63102   963695.0  208844.0  51981.0  37789.0
# 63103  1001585.0  211472.0  52663.0  37443.0

# %%
percapita.sample(5)  
# Muestra 5 filas aleatorias del DataFrame
# Out:
#                  País ISO 3166-1 alpha-3   Año      Total     Carbón  \
# 51413   Islas Salomón                SLB  1755        NaN        NaN
# 59614        Tanzania                TZA  1796        NaN        NaN
# 56157  Timor Oriental                TLS  1875        NaN        NaN
# 44819     Puerto Rico                PRI  1961        0.0        NaN
# 39081    Países Bajos                NLD  1935  4418436.0  4009373.0
#
#          Aceite  Gas  Cemento  Quema  Otros
# 51413       NaN  NaN      NaN    NaN    NaN
# 59614       NaN  NaN      NaN    NaN    NaN
# 56157       NaN  NaN      NaN    NaN    NaN
# 44819       NaN  NaN      NaN    NaN    NaN
# 39081  387948.0  0.0  21115.0    0.0    NaN

# %%
fuentes = pd.read_excel("emisiones_CO2.xlsx",sheet_name= 'fuentes')

# %%
fuentes.tail(5)
# Out:
#          País ISO 3166-1 alpha-3   Año                                 Total  \
# 63099  Global                WLD  2017  CDIAC 2022, BP, and Sum of countries
# 63100  Global                WLD  2018  CDIAC 2022, BP, and Sum of countries
# 63101  Global                WLD  2019  CDIAC 2022, BP, and Sum of countries
# 63102  Global                WLD  2020  CDIAC 2022, BP, and Sum of countries
# 63103  Global                WLD  2021  CDIAC 2022, BP, and Sum of countries
#
#                   Carbón             Aceite                Gas        Cemento  \
# 63099  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63100  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63101  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63102  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63103  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
#
# ...

# %% [markdown]
# #### selecionar intervalo de columnas

# %%
intervalo = pd.read_excel("emisiones_CO2.xlsx", sheet_name= 'emisiones_C02' , usecols= 'A:D')
intervalo
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %% [markdown]
# #### seleccionar numeros de filas

# %%
intervalo_2 = pd.read_excel("emisiones_CO2.xlsx", sheet_name= 'emisiones_C02' , usecols= 'A:D', nrows= 10)
intervalo_2
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %% [markdown]
# #### escribir archivo excel

# %%
intervalo.to_excel("emisiones_CO2_intervalo.xlsx", index= False)

# %% [markdown]
# #### leer archivo creado

# %%
pd.read_excel("emisiones_CO2_intervalo.xlsx")
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %% [markdown]
# ## LEER ARCHIVOS EXCEL EN GOOGLE SHEETS

# %% [markdown]
# link : https://docs.google.com/spreadsheets/d/1hV4_35gr1sYN-SfcSzsak0lB0QSb5iWoVOASfsmE4iw/edit?usp=sharing
#
# https://docs.google.com/spreadsheets/d/1hV4_35gr1sYN-SfcSzsak0lB0QSb5iWoVOASfsmE4iw/edit?usp=sharing

# %%
sheet_id = '1hV4_35gr1sYN-SfcSzsak0lB0QSb5iWoVOASfsmE4iw'

url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

#url = 'https://docs.google.com/spreadsheets/d/1hV4_35gr1sYN-SfcSzsak0lB0QSb5iWoVOASfsmE4iw/edit?usp=sharing'

print(url)
# Out:
# https://docs.google.com/spreadsheets/d/1hV4_35gr1sYN-SfcSzsak0lB0QSb5iWoVOASfsmE4iw/gviz/tq?tqx=out:csv&sheet

# %%
datos_co2_sheets = pd.read_csv(url)

datos_co2_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año           Total          Carbón  \
# 0      Afganistán                AFG  1750               0             NaN
# 1      Afganistán                AFG  1751               0             NaN
# 2      Afganistán                AFG  1752               0             NaN
# 3      Afganistán                AFG  1753               0             NaN
# 4      Afganistán                AFG  1754               0             NaN
# ...           ...                ...   ...             ...             ...
# 63099      Global                WLD  2017  36,096,739,276  14,506,973,805
# 63100      Global                WLD  2018  36,826,506,600  14,746,830,688
# 63101      Global                WLD  2019  37,082,558,969  14,725,978,025
# 63102      Global                WLD  2020  35,264,085,734  14,174,564,010
# 63103      Global                WLD  2021  37,123,850,352  14,979,598,083
#
# ...

# %% [markdown]
# ## **LEER HOJA ESPECIFICA** "emisiones_percapita"

# %%
sheet_id = '1hV4_35gr1sYN-SfcSzsak0lB0QSb5iWoVOASfsmE4iw'
sheet_name = 'emisiones_percapita'

url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

print(url_percapita)
# Out:
# https://docs.google.com/spreadsheets/d/1hV4_35gr1sYN-SfcSzsak0lB0QSb5iWoVOASfsmE4iw/gviz/tq?tqx=out:csv&sheet=emisiones_percapita

# %%
percapita_sheets = pd.read_csv(url_percapita)

percapita_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 0      Afganistán                AFG  1750        NaN        NaN        NaN
# 1      Afganistán                AFG  1751        NaN        NaN        NaN
# 2      Afganistán                AFG  1752        NaN        NaN        NaN
# 3      Afganistán                AFG  1753        NaN        NaN        NaN
# 4      Afganistán                AFG  1754        NaN        NaN        NaN
# ...           ...                ...   ...        ...        ...        ...
# 63099      Global                WLD  2017  4,749,682  1,908,857  1,610,910
# 63100      Global                WLD  2018  4,792,753  1,919,213  1,596,350
# 63101      Global                WLD  2019  4,775,633  1,896,468  1,589,920
# 63102      Global                WLD  2020  4,497,423  1,807,760  1,427,353
# 63103      Global                WLD  2021  4,693,699  1,893,923  1,496,614
#
#              Gas  Cemento   Quema   Otros
# ...

# %% [markdown]
# ## **LEER HOJA ESPECIFICA** "fuentes"

# %%
sheet_id = '1hV4_35gr1sYN-SfcSzsak0lB0QSb5iWoVOASfsmE4iw'
sheet_name = 'fuentes' # NOMBRE DE LA HOJA

url_fuentes = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

print(url_fuentes)
# Out:
# https://docs.google.com/spreadsheets/d/1hV4_35gr1sYN-SfcSzsak0lB0QSb5iWoVOASfsmE4iw/gviz/tq?tqx=out:csv&sheet=fuentes

# %%
fuentes_sheets = pd.read_csv(url_fuentes)

fuentes_sheets.head(5)
# Out:
#          País ISO 3166-1 alpha-3   Año   Total  Carbón  Aceite     Gas  \
# 0  Afganistán                AFG  1750  [NONE]  [NONE]  [NONE]  [NONE]
# 1  Afganistán                AFG  1751  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afganistán                AFG  1752  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afganistán                AFG  1753  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afganistán                AFG  1754  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cemento   Quema   Otros Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# 3  [NONE]  [NONE]  [NONE]     [NONE]
# 4  [NONE]  [NONE]  [NONE]     [NONE]

# %% [markdown]
# Desafío: leyendo datos de otro link

# %% [markdown]
# https://docs.google.com/spreadsheets/d/14hPDO3Dmggshh_H7_LUBQMclf8D4OUuAqbpUpOl3qHs/edit?usp=sharing
#
# sheet_id_2 = '14hPDO3Dmggshh_H7_LUBQMclf8D4OUuAqbpUpOl3qHs'
#
# url_carbon = f'https://docs.google.com/spreadsheets/d/{sheet_id_2}/edit?usp=sharing'

# %%
sheet_id_2 = '14hPDO3Dmggshh_H7_LUBQMclf8D4OUuAqbpUpOl3qHs'

url_carbon = f'https://docs.google.com/spreadsheets/d/{sheet_id_2}/gviz/tq?tqx=out:csv&sheet='

print(url_carbon)
# Out:
# https://docs.google.com/spreadsheets/d/14hPDO3Dmggshh_H7_LUBQMclf8D4OUuAqbpUpOl3qHs/gviz/tq?tqx=out:csv&sheet=

# %%
carbon_sheets = pd.read_csv(url_carbon)

carbon_sheets.head(5)
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name           1990         1991  \
# 0  CO2 emissions (metric tons per capita)            NaN          NaN
# 1  CO2 emissions (metric tons per capita)    191,745,115  167,681,579
# 2  CO2 emissions (metric tons per capita)    553,661,955  544,538,649
# 3  CO2 emissions (metric tons per capita)  1,819,541,634  124,281,022
# 4  CO2 emissions (metric tons per capita)  7,521,831,658  723,537,924
#
#           1992           1993           1994           1995  ...  \
# 0          NaN            NaN            NaN            NaN  ...
# 1   95,957,742      8,472,111     75,545,827     68,467,956  ...
# ...
