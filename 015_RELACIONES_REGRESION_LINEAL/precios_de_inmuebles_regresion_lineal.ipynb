# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2145-data-science-probando-relaciones-con-regresion-lineal/blob/main/precios_de_inmuebles_regresion_lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Precificación inmobiliaria**
#
# **Objetivo**: Estimar los precios de los inmuebles.
#  * Identificar los aspectos que tienen más influencia en la precificación de los inmuebles.
#  * Entender cuál de todos estos aspectos es el más relevante.
#  * Precificar un inmueble nuevo.
#
# Base de datos simplificada e inspirada en [House Prices](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques)
#
#
#
# ![](https://i.imgur.com/A8X79yq.jpeg)

# %% [markdown]
# # 1. Ajustando una recta

# %% [markdown]
# ## Conociendo los datos

# %%
#Leyendo los datos
import pandas as pd

datos = pd.read_csv('precios_casas.csv')
datos.head()
# Out:
#    Id  area_primer_piso  tiene_segundo_piso  area_segundo_piso  \
# 0   1           79.5224                   1            79.3366
# 1   2          117.2398                   0             0.0000
# 2   3           85.4680                   1            80.4514
# 3   4           89.2769                   1            70.2324
# 4   5          106.3705                   1            97.8237
#
#    cantidad_banos  capacidad_carros_garage  calidad_de_cocina_excelente  \
# 0               2                      548                            0
# 1               2                      460                            0
# 2               2                      608                            0
# 3               1                      642                            0
# 4               2                      836                            0
#
#    precio_de_venta
# 0        1027905.0
# 1         894795.0
# 2        1101855.0
# 3         690200.0
# 4        1232500.0

# %%
#Cuáles factores fueron colectados
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1438 entries, 0 to 1437
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Id                           1438 non-null   int64
#  1   area_primer_piso             1438 non-null   float64
#  2   tiene_segundo_piso           1438 non-null   int64
#  3   area_segundo_piso            1438 non-null   float64
#  4   cantidad_banos               1438 non-null   int64
#  5   capacidad_carros_garage      1438 non-null   int64
#  6   calidad_de_cocina_excelente  1438 non-null   int64
#  7   precio_de_venta              1438 non-null   float64
# dtypes: float64(3), int64(5)
# memory usage: 90.0 KB

# %%
#eliminamos la columna Id
#ya que no es relevante para el análisis
datos = datos.drop(columns='Id')
datos.columns
# Out:
# Index(['area_primer_piso', 'tiene_segundo_piso', 'area_segundo_piso',
#        'cantidad_banos', 'capacidad_carros_garage',
#        'calidad_de_cocina_excelente', 'precio_de_venta'],
#       dtype='object')

# %% [markdown]
# ## Correlación
#
# **¿Cuáles factores están relacionados con el precio de la casa? ¿Cómo es esa relación?**
#
# El coeficiente de correlación de Pearson nos permite medir la relación lineal entre variables, ofreciendo una escala que varía de -1 a 1, la cual interpretamos según su intensidad y dirección:
#
# * **-1**: correlación negativa perfecta: a medida que una variable aumenta, la otra disminuye.
# * **0**: no hay relación lineal entre las variables.
# * **1**: correlación positiva perfecta: a medida que una variable aumenta, la otra también aumenta.

# %%
# Correlación
corr = datos.corr()
corr["precio_de_venta"]
# Out:
# area_primer_piso               0.616557
# tiene_segundo_piso             0.138541
# area_segundo_piso              0.305311
# cantidad_banos                 0.563132
# capacidad_carros_garage        0.640214
# calidad_de_cocina_excelente    0.496223
# precio_de_venta                1.000000
# Name: precio_de_venta, dtype: float64

# %%
# Actividad
# Cuáles factores están más correlacionados?
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Leyendo datos
datos = pd.read_csv("precios_casas.csv")
datos = datos.drop(columns = "Id")

# Correlación
corr = datos.corr()

# ¿Qué factores están más correlacionados?

# Generar una máscara para el triángulo superior
mascara = np.zeros_like(corr, dtype=bool)
mascara[np.triu_indices_from(mascara)] = True

# Configurar la figura de matplotlib
f, ax = plt.subplots(figsize=(11, 9))

# Generar el mapa de calor (heatmap)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr, mask=mascara, cmap=cmap, vmax=1, vmin=-1, center=0,
            square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .5})

# Mostrar el mapa de calor (heatmap)
plt.show()

# %% [markdown]
# ## Relacionando variables

# %%
# importando los paquetes para la visualización
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Cómo se relacionan el área construída y el precio del inmueble?
plt.scatter(datos['area_primer_piso'], datos['precio_de_venta'])
plt.title('Relación entre área del primer piso y precio de venta')
plt.xlabel('Área del primer piso (m²)')
plt.ylabel('Precio de venta ($)')
plt.show()

# %%
# Aparentemente mientras mayor es el área del primer piso, mayor es el precio de la casa.
# E si quisieramos trazar una línea que nos permita describir este comportamiento?
plt.scatter(datos['area_primer_piso'], datos['precio_de_venta'])
plt.axline(xy1=(40,300000), xy2=(175, 1500000), color= 'red')
plt.title('Relación entre área del primer piso y precio de venta')
plt.xlabel('Área del primer piso (m²)')
plt.ylabel('Precio de venta ($)')
plt.show()

# %% [markdown]
# ## Mejor recta

# %%
# Usando seaborn para trazar una línea de regresión
px.scatter(datos, x='area_primer_piso', y='precio_de_venta',trendline_color_override='red', trendline='ols')

# %% [markdown]
# # 2. Explicando la recta
# Ajustamos una recta entre los $m^2$ del primer piso y el precio de la casa. Queremos explicar el precio de la casa a partir de su tamaño, por eso decimos que:
#
# * Variable explicativa/independiente: Área del primer piso
# * Variable de respuesta/dependiente: Precio de la casa

# %%
#Quién es nuestra variable de respuesta?
sns.displot(datos['precio_de_venta'], kde=True, color='green')
plt.title('Distribución del precio de venta')
plt.show()

# %% [markdown]
# ### Separando datos para entrenamiento y para prueba
#
# El conjunto de **entrenamiento** se utiliza para ajustar el modelo, mientras que el conjunto de **prueba** se usa para evaluar su desempeño al predecir precios de viviendas no vistos durante el entrenamiento, lo que ayuda a la generalización del modelo.

# %%
# import train_test_split
from sklearn.model_selection import train_test_split

y = datos['precio_de_venta']
X = datos.drop(columns=['precio_de_venta'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=230) 
#garantizar que los resultados sean reproducibles

# %%
#Datos de entrenamiento para usar la fórmula
df_train = pd.DataFrame(X_train)
df_train['precio_de_venta'] = y_train

# %%
# import ols
from statsmodels.formula.api import ols

# %%
# ajustando el primer modelo
modelo_0 = ols('precio_de_venta ~ area_primer_piso', data=df_train).fit()

# %% [markdown]
# ## Analizando los coeficientes
#
# (intensidad, dirección y significancia)

# %%
# visualizando los parámetros
modelo_0.params
# Out:
# Intercept           152909.288334
# area_primer_piso      6793.641641
# dtype: float64

# %%
# El resumen del modelo
modelo_0.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        precio_de_venta   R-squared:                       0.377
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     608.3
# Date:                Wed, 09 Jul 2025   Prob (F-statistic):          2.22e-105
# Time:                        21:48:44   Log-Likelihood:                -14082.
# No. Observations:                1006   AIC:                         2.817e+04
# Df Residuals:                    1004   BIC:                         2.818e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         1.529e+05   3.07e+04      4.981      0.000    9.27e+04    2.13e+05
# area_primer_piso  6793.6416    275.455     24.663      0.000    6253.109    7334.175
# ==============================================================================
# Omnibus:                      190.778   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              482.457
# Skew:                           0.998   Prob(JB):                    1.72e-105
# Kurtosis:                       5.743   Cond. No.                         373.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# - El **punto de intercepción** es el valor esperado del precio de la casa cuando todas las demás variables son cero. En este caso, cuando todas las demás variables, incluida el área del primer piso, son cero, el precio esperado de la casa es de $145.196,40. No siempre se tiene una interpretación práctica para este número.
#
# - El **efecto individual** del área es de \$6.833,97. Esto indica que por cada metro cuadrado adicional al área del primer piso, se espera que el precio de la casa aumente en promedio \$6.833,97.
#
# <img src="https://i.ibb.co/CJwfMgW/coeficientes.png" alt="coeficientes" border="0">

# %% [markdown]
# ## Explicabilidad del modelo
#
# **¿En qué medida la variación del área explica los diversos precios de las casas?**
#
# En este caso, recurrimos a la métrica R², el coeficiente de determinación. El R² varía de 0 a 1, donde 1 indica un ajuste perfecto del modelo a los datos, es decir, todas las variaciones en la variable dependiente son explicadas por las variables independientes en el modelo. Por otro lado, un R² de 0 indica que el modelo no explica ninguna variabilidad en la variable dependiente.

# %%
# observando el R²
modelo_0.rsquared
# Out:
# np.float64(0.3772801099429788)

# %% [markdown]
# ## Entendiendo el resíduo

# %%
# Quiénes son los residuos?
modelo_0.resid
# Out:
# 1303   -193023.838744
# 326    -144522.356193
# 386     399612.747641
# 615     -68449.596607
# 236     166010.592859
#             ...
# 777     465872.680999
# 271    -497642.319788
# 723     461150.204718
# 560    -540482.733402
# 768     -37547.820756
# Length: 1006, dtype: float64

# %%
# Cómo están distribuidos
modelo_0.resid.hist()
plt.title('Distribución de los residuos')
plt.show()

# %% [markdown]
# <img src="https://i.ibb.co/zGTB35V/residuos.png" alt="residuos" border="0">

# %% [markdown]
# ## Obteniendo el R² de la previsión

# %%
# definiendo la 'Y' prevista
y_predict = modelo_0.predict(X_test)

# %%
# importando el r2_score
from sklearn.metrics import r2_score

# %%
# mostrando el resultado de r²
print("R² score:",round(r2_score(y_test, y_predict),2))
# Out:
# R² score: 0.39

# %% [markdown]
# # 3. Añadiendo otras características
#
# El modelo con un solo factor nos mostró un R² de 0.38, es decir, aproximadamente el 38% de la variación observada en los precios de las casas puede explicarse por la variación en el área.
# Esto indica que aún existe una cantidad significativa de variación que no está siendo capturada por este modelo específico. Analizaremos otros factores para explicar el precio de las casas.

# %% [markdown]
# ## Analizando los factores

# %%
# cuáles otras características podrían explicar el precio de los inmuebles?
sns.pairplot(datos)

# %%
#Vamos a analizar solamente y_vars='precio_de_venta'
sns.pairplot(datos, y_vars=['area_primer_piso', 'area_segundo_piso', 'cantidad_banos'],x_vars=['precio_de_venta'])

# %% [markdown]
# ## Añadiendo factores al modelo

# %%
# importando la api de statsmodels
import statsmodels.api as sm

# %%
# Añadiendo una constante
X_train_const = sm.add_constant(X_train)
X_train.head()
# Out:
#       area_primer_piso  tiene_segundo_piso  area_segundo_piso  cantidad_banos  \
# 1303           65.7732                   0             0.0000               1
# 326            55.3684                   1            55.3684               1
# 386            74.6916                   1           107.4853               2
# 615           103.6764                   0             0.0000               1
# 236            94.2006                   1            67.8170               2
#
#       capacidad_carros_garage  calidad_de_cocina_excelente
# 1303                        0                            0
# 326                       189                            0
# 386                       560                            0
# 615                       440                            0
# 236                       457                            0

# %%
X_train.columns
# Out:
# Index(['area_primer_piso', 'tiene_segundo_piso', 'area_segundo_piso',
#        'cantidad_banos', 'capacidad_carros_garage',
#        'calidad_de_cocina_excelente'],
#       dtype='object')

# %%
# Creando el modelo de regresión (con todas las variables): saturado
modelo_1 = sm.OLS(y_train, X_train[['area_primer_piso', 'tiene_segundo_piso', 'area_segundo_piso',
       'cantidad_banos', 'capacidad_carros_garage',
       'calidad_de_cocina_excelente']]).fit()

# %%
# Modelo sin el área del segundo piso
modelo_2 = sm.OLS(y_train, X_train[['area_primer_piso', 'tiene_segundo_piso',
       'cantidad_banos', 'capacidad_carros_garage',
       'calidad_de_cocina_excelente']]).fit()

# %%
# Modelo sin la información del garage
# Modelo sin el área del segundo piso
modelo_3 = sm.OLS(y_train, X_train[['area_primer_piso', 'tiene_segundo_piso',
       'cantidad_banos','calidad_de_cocina_excelente']]).fit()

# %%
# Resumen del modelos
modelos = [modelo_0 , modelo_1 , modelo_2 , modelo_3]

for i , j in enumerate(modelos):
    print(f'**************************************************************************************\n********************* El modelo {i} tiene el siguiente resumen *************************\n**************************************************************************************' )
    print(j.summary(), '\n\n')
# Out:
# **************************************************************************************
# ********************* El modelo 0 tiene el siguiente resumen *************************
# **************************************************************************************
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        precio_de_venta   R-squared:                       0.377
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     608.3
# Date:                Wed, 09 Jul 2025   Prob (F-statistic):          2.22e-105
# Time:                        21:48:49   Log-Likelihood:                -14082.
# No. Observations:                1006   AIC:                         2.817e+04
# Df Residuals:                    1004   BIC:                         2.818e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept         1.529e+05   3.07e+04      4.981      0.000    9.27e+04    2.13e+05
# area_primer_piso  6793.6416    275.455     24.663      0.000    6253.109    7334.175
# ==============================================================================
# Omnibus:                      190.778   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              482.457
# Skew:                           0.998   Prob(JB):                    1.72e-105
# Kurtosis:                       5.743   Cond. No.                         373.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# **************************************************************************************
# ********************* El modelo 1 tiene el siguiente resumen *************************
# **************************************************************************************
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:        precio_de_venta   R-squared (uncentered):                   0.961
# Model:                            OLS   Adj. R-squared (uncentered):              0.961
# Method:                 Least Squares   F-statistic:                              4103.
# Date:                Wed, 09 Jul 2025   Prob (F-statistic):                        0.00
# Time:                        21:48:49   Log-Likelihood:                         -13642.
# No. Observations:                1006   AIC:                                  2.730e+04
# Df Residuals:                    1000   BIC:                                  2.733e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# area_primer_piso             4501.4119    207.689     21.674      0.000    4093.856    4908.968
# tiene_segundo_piso          -1.662e+05   2.98e+04     -5.582      0.000   -2.25e+05   -1.08e+05
# area_segundo_piso            4964.2887    401.278     12.371      0.000    4176.844    5751.733
# cantidad_banos               5.762e+04   1.41e+04      4.074      0.000    2.99e+04    8.54e+04
# capacidad_carros_garage       426.3762     34.781     12.259      0.000     358.123     494.629
# calidad_de_cocina_excelente  3.921e+05   2.44e+04     16.052      0.000    3.44e+05     4.4e+05
# ==============================================================================
# Omnibus:                      142.860   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1074.519
# Skew:                           0.395   Prob(JB):                    4.69e-234
# Kurtosis:                       8.001   Cond. No.                     2.67e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# **************************************************************************************
# ********************* El modelo 2 tiene el siguiente resumen *************************
# **************************************************************************************
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:        precio_de_venta   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.955
# Method:                 Least Squares   F-statistic:                              4248.
# Date:                Wed, 09 Jul 2025   Prob (F-statistic):                        0.00
# Time:                        21:48:49   Log-Likelihood:                         -13714.
# No. Observations:                1006   AIC:                                  2.744e+04
# Df Residuals:                    1001   BIC:                                  2.746e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# area_primer_piso             3795.3209    214.322     17.708      0.000    3374.748    4215.894
# tiene_segundo_piso           1.578e+05   1.52e+04     10.369      0.000    1.28e+05    1.88e+05
# cantidad_banos               9.521e+04   1.48e+04      6.423      0.000    6.61e+04    1.24e+05
# capacidad_carros_garage       501.5639     36.755     13.646      0.000     429.438     573.690
# calidad_de_cocina_excelente  4.211e+05   2.61e+04     16.137      0.000     3.7e+05    4.72e+05
# ==============================================================================
# Omnibus:                      236.145   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1893.228
# Skew:                           0.842   Prob(JB):                         0.00
# Kurtosis:                       9.506   Cond. No.                     2.17e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.17e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# **************************************************************************************
# ********************* El modelo 3 tiene el siguiente resumen *************************
# **************************************************************************************
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:        precio_de_venta   R-squared (uncentered):                   0.947
# Model:                            OLS   Adj. R-squared (uncentered):              0.946
# Method:                 Least Squares   F-statistic:                              4442.
# Date:                Wed, 09 Jul 2025   Prob (F-statistic):                        0.00
# Time:                        21:48:49   Log-Likelihood:                         -13800.
# No. Observations:                1006   AIC:                                  2.761e+04
# Df Residuals:                    1002   BIC:                                  2.763e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# area_primer_piso             5232.5450    203.179     25.753      0.000    4833.839    5631.250
# tiene_segundo_piso           1.887e+05   1.64e+04     11.525      0.000    1.57e+05    2.21e+05
# cantidad_banos               1.378e+05   1.58e+04      8.736      0.000    1.07e+05    1.69e+05
# calidad_de_cocina_excelente   4.77e+05   2.81e+04     17.005      0.000    4.22e+05    5.32e+05
# ==============================================================================
# Omnibus:                      183.744   Durbin-Watson:                   2.102
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              942.947
# Skew:                           0.737   Prob(JB):                    1.74e-205
# Kurtosis:                       7.508   Cond. No.                         452.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
for i,j in enumerate(modelos):
    print(f'El coeficiente de determinacion R² del modelo {i}: {j.rsquared.round(2)}' )
# Out:
# El coeficiente de determinacion R² del modelo 0: 0.38
# El coeficiente de determinacion R² del modelo 1: 0.96
# El coeficiente de determinacion R² del modelo 2: 0.95
# El coeficiente de determinacion R² del modelo 3: 0.95

# %% [markdown]
# ## Comparando los modelos
# Cuál es el modelo?

# %%
# Cuántos parámetros tiene el modelo?
modelo_3.params
# Out:
# area_primer_piso                 5232.544951
# tiene_segundo_piso             188736.992391
# cantidad_banos                 137794.474201
# calidad_de_cocina_excelente    477000.426315
# dtype: float64

# %% [markdown]
# # 4. Precificando las casas

# %% [markdown]
# ## Obteniendo el R² de la previsión

# %%
# Añadiendo una constante en X_test
X_test = sm.add_constant(X_test)
X_test.head()
# Out:
#       const  area_primer_piso  tiene_segundo_piso  area_segundo_piso  \
# 997     1.0           94.9438                   0             0.0000
# 805     1.0           74.1342                   1            78.2218
# 1138    1.0          117.5185                   0             0.0000
# 1391    1.0          171.3076                   0             0.0000
# 516     1.0          117.6114                   0             0.0000
#
#       cantidad_banos  capacidad_carros_garage  calidad_de_cocina_excelente
# 997                1                      280                            0
# 805                2                      595                            0
# 1138               2                      502                            0
# 1391               2                      620                            0
# 516                2                      453                            0

# %%
# Previsión con el modelo 3
prevision_3 = modelo_3.predict(X_test[['area_primer_piso', 'tiene_segundo_piso',
                                       'cantidad_banos','calidad_de_cocina_excelente']])

# %%
# Cuál es el r² de la previsión?
print(f' El coeficiente R² de la previsión es: {modelo_3.rsquared.round(2)}')
# Out:
#  El coeficiente R² de la previsión es: 0.95

# %%
# Cuál es el R² del entrenamiento?
print(f' El coeficiente R² con respecto a la base de entrenamiento es: {round(r2_score(y_test, prevision_3),2)}')
# Out:
#  El coeficiente R² con respecto a la base de entrenamiento es: 0.64

# %% [markdown]
# ## Precificando una casa
#
# <img src="https://i.ibb.co/SvG4V4j/costo.png" alt="costo" border="0">

# %%
#Nuevo inmueble
nuevo_inmueble = pd.DataFrame({
    #'const':[1],
    'area_primer_piso':[120],
    'tiene_segundo_piso':[1],
    'cantidad_banos':[2],
    'calidad_de_cocina_excelente':[0]
})

# %%
# Cuál es el precio del inmueble de acuerdo con el modelo 0?
modelo_0.predict(nuevo_inmueble['area_primer_piso']).round(2)
# Out:
# 0    968146.29
# dtype: float64

# %%
#Cuál es el precio del inmueble de acuerdo con el modelo 3?
modelo_3.predict(nuevo_inmueble.round(2))
# Out:
# 0    1.092231e+06
# dtype: float64

# %%
modelo_3.params
# Out:
# area_primer_piso                 5232.544951
# tiene_segundo_piso             188736.992391
# cantidad_banos                 137794.474201
# calidad_de_cocina_excelente    477000.426315
# dtype: float64

# %% [markdown]
# ## Precificando varias casas
#
# <img src="https://i.imgur.com/i0skFlB.jpeg" width="600"/>

# %%
# Leyendo varias casas?
nuevas_casas = pd.read_csv('nuevas_casas.csv', sep =';')
nuevas_casas.head()
# Out:
#    Casa  area_primer_piso  tiene_segundo_piso  cantidad_banos  \
# 0     1               150                   1               2
# 1     2               180                   0               3
# 2     3               120                   1               2
# 3     4               200                   1               3
# 4     5               160                   0               2
#
#    calidad_de_cocina_excelente
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            1

# %%
nuevas_casas.drop(columns='Casa', inplace=True)
nuevas_casas.head()
# Out:
#    area_primer_piso  tiene_segundo_piso  cantidad_banos  \
# 0               150                   1               2
# 1               180                   0               3
# 2               120                   1               2
# 3               200                   1               3
# 4               160                   0               2
#
#    calidad_de_cocina_excelente
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            1

# %%
# Añadiendo una constante
nuevas_casas = sm.add_constant(nuevas_casas)
nuevas_casas.head()

# %%
# Cuál es el precio de estas nuevas casas?
#precio_casas = pd.DataFrame()
nuevas_casas['Precio de venta'] = modelo_3.predict(nuevas_casas).round(2)
nuevas_casas
# Out:
#    area_primer_piso  tiene_segundo_piso  cantidad_banos  \
# 0               150                   1               2
# 1               180                   0               3
# 2               120                   1               2
# 3               200                   1               3
# 4               160                   0               2
# 5               140                   1               2
# 6               170                   0               3
# 7               190                   1               2
# 8               130                   0               2
# 9               180                   1               3
#
#    calidad_de_cocina_excelente  Precio de venta
# 0                            1       1726208.11
# 1                            1       1832241.94
# 2                            1       1569231.76
# 3                            1       2125629.83
# 4                            1       1589796.57
# 5                            0       1196882.23
# 6                            0       1302916.06
# 7                            0       1458509.48
# 8                            0        955819.79
# 9                            0       1543978.51

# %% [markdown]
# # 5. Investigando el modelo

# %% [markdown]
# ## Multicolinearidad
#
# Cuando dos o más cosas que estás intentando estudiar son tan parecidas que es difícil determinar cuánto está influyendo cada una de ellas en el resultado.

# %%
# importar el VIF de statsmodel
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

# %%
explicativas_1 = ['area_primer_piso', 'tiene_segundo_piso', 'area_segundo_piso',
                'cantidad_banos', 'capacidad_carros_garage',
                'calidad_de_cocina_excelente']
explicativas_2 = ['area_primer_piso', 'tiene_segundo_piso', 
                'cantidad_banos', 'capacidad_carros_garage',
                'calidad_de_cocina_excelente']
explicativas_3 = ['area_primer_piso', 'tiene_segundo_piso', 
                'cantidad_banos', 'calidad_de_cocina_excelente']

# %%
# VIF 1
vif_1 = pd.DataFrame()
vif_1['variables'] = explicativas_1
vif_1['VIF'] = [vif(X_train[explicativas_1],i ) for i in range(len(explicativas_1))]
vif_1
# Out:
#                      variables        VIF
# 0             area_primer_piso  15.217040
# 1           tiene_segundo_piso  10.517606
# 2            area_segundo_piso  11.301122
# 3               cantidad_banos  15.270554
# 4      capacidad_carros_garage   9.188180
# 5  calidad_de_cocina_excelente   1.196111

# %%
# VIF 3
vif_3 = pd.DataFrame()
vif_3['variables'] = explicativas_3
vif_3['VIF'] = [vif(X_train[explicativas_3],i ) for i in range(len(explicativas_3))]
vif_3
# Out:
#                      variables        VIF
# 0             area_primer_piso  10.670586
# 1           tiene_segundo_piso   2.330279
# 2               cantidad_banos  13.919879
# 3  calidad_de_cocina_excelente   1.155863

# %% [markdown]
# ## Análisis de los residuos
#
# Residuos: la discrepancia entre los valores reales y los valores que el modelo predice para los mismos puntos de datos.

# %% [markdown]
# <img src="https://i.ibb.co/9bmySbm/heterocedasticidad.png" alt="heterocedasticidad" border="0">
